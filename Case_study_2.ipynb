# %% [markdown]
# # **Case Study – Library Fine Calculator**

# %% [markdown]
# Instructions:
#
# Create variables:
#
# student_name
#
# book_name
#
# days_late
#
# fine_per_day
#
# Use input() function to get details from the user.
#
# Use type casting:
#
# int() for days_late
#
# float() for fine_per_day
#
# Calculate:
#
# total_fine = days_late * fine_per_day
#
# Display all details using:
#
# print()
#
# f-string
#
# Display datatype of important variables using:
#
# type()

# %%
#Use input() function to get details from the user.

student_name =input("Enter the student name:")

book_name = input("Enter the book name:")

days_late = int(input("Enter the days late:"))

fine_per_day = float(input("Enter the fine per day"))

#Calculation of total fine

total_fine = days_late * fine_per_day

#Displaying all details

print("/n----Library Fine Details----")
print(f"Student name:{student_name}")
print(f"Book name:{book_name}")
print(f"Days late:{days_late}")
print(f"Fine per day:{fine_per_day}")

print(f"Total fine:{total_fine}")

#Data Types
print(type(student_name))
print(type(days_late))
print(type(fine_per_day))
# Out:
# Enter the student name:Amy Johnson
# Enter the book name:Dynamics
# Enter the days late:7
# Enter the fine per day30
# /n----Library Fine Details----
# Student name:Amy Johnson
# Book name:Dynamics
# Days late:7
# Fine per day:30.0
# Total fine:210.0
# <class 'str'>
# <class 'int'>
# <class 'float'>
