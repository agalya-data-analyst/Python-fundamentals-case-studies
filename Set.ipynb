# %% [markdown]
# Case Study – Student Course Registration System using Set
# Instructions:
#
# Create a set named courses with course names: Python, SQL, Power BI, Python, Excel
#
# Perform set operations: • Add course using add()
# • Add multiple courses using update()
# • Remove course using remove() and discard()
#
# Display all courses and total number of courses using len()

# %%
# Case Study – Student Course Registration System using Set

# Creating set

courses = {"Python","SQL", "Power BI", "Python", "Excel"}

print(courses)
# Out:
# {'Excel', 'SQL', 'Power BI', 'Python'}

# %%
#Add course using add()
courses.add("SAP")

print(courses)
# Out:
# {'SQL', 'Power BI', 'SAP', 'Excel', 'Python'}

# %%
#Add multiple courses using update()

courses.update(["Java","Advanced Excel"])

print(courses)
# Out:
# {'Java', 'SQL', 'Power BI', 'SAP', 'Excel', 'Advanced Excel', 'Python'}

# %%
# Remove course using remove()
courses.remove("Advanced Excel")
print(courses)
# Out:
# {'Java', 'SQL', 'Power BI', 'SAP', 'Excel', 'Python'}

# %%
#Remove course using  discard()

courses.discard("SQL")

print(courses)
# Out:
# {'Java', 'Power BI', 'SAP', 'Excel', 'Python'}

# %%
#total number of courses using len()

len(courses)
# Out:
# 5

# %%
#Display all courses
print("All course:",courses)
# Out:
# All course: {'Java', 'Power BI', 'SAP', 'Excel', 'Python'}
