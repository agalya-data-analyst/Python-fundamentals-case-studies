# %% [markdown]
# Creating Dictionary

# %%
student ={"student id" : "EN001",
          "name" : "Amy",
          "age" : 30,
          "course": "python"}
print(student)
# Out:
# {'student id': 'EN001', 'name': 'Amy', 'age': 30, 'course': 'python'}

# %% [markdown]
# Case Study – Student Data Management System
# Instructions:
#
# Create a dictionary named student with the following keys: name, age, course
#
# Store multiple students' data using lists as values.
#
# Add one new student details to the dictionary:
#
# • Append new name to name list
#
# • Append new age to age list
#
# • Append new course to course list
#
# Display all student details using dictionary keys.
#
# Access and display:
#
# • First student's details using indexing
#
# • Newly added student's details using indexin

# %%
#Create a dictionary named student with the following keys: name, age, course

student = {
    "name":["Amy","Merlin","John"],
    "Age":[29,30,31],
    "course":["Data analysis","Java","Python"]
    }

print(student)
# Out:
# {'name': ['Amy', 'Merlin', 'John'], 'Age': [29, 30, 31], 'course': ['Data analysis', 'Java', 'Python']}

# %%
#• Append new name to name list
#• Append new age to age list
# Append new course to course list
student["name"].append("Gale")
student["Age"].append(24)
student["course"].append("software development")

print(student)
# Out:
# {'name': ['Amy', 'Merlin', 'John', 'Gale', 'Gale'], 'Age': [29, 30, 31, 24], 'course': ['Data analysis', 'Java', 'Python', 'software development']}

# %%
#Display all student details using dictionary keys.
